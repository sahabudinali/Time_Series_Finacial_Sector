# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

# %%
import os
from datetime import datetime
import pandas_datareader.data as web
os.environ['ALPHAVANTAGE_API_KEY'] = 'my_key'
f = web.DataReader("AAPL", "av-daily", start=datetime(2017, 1, 1),
                   end=datetime(2020, 8, 30))
f.index.names = ['Date']

f.head(5)
# Out:
#               open      high     low   close    volume
# Date
# 2017-01-03  115.80  116.3300  114.76  116.15  28781865
# 2017-01-04  115.85  116.5100  115.75  116.02  21118116
# 2017-01-05  115.92  116.8642  115.81  116.61  22193587
# 2017-01-06  116.78  118.1600  116.47  117.91  31751900
# 2017-01-09  117.95  119.4300  117.94  118.99  33561948

# %%
f.describe()
# Out:
#              open        high         low       close        volume
# count  921.000000  921.000000  921.000000  921.000000  9.210000e+02
# mean   209.512476  211.749265  207.550957  209.808670  3.186257e+07
# std     70.676128   71.875973   69.681324   70.969244  1.471821e+07
# min    115.800000  116.330000  114.760000  116.020000  1.136204e+07
# 25%    160.860000  163.400000  159.890000  161.470000  2.189659e+07
# 50%    187.990000  189.530000  186.360000  188.150000  2.787622e+07
# 75%    227.250000  228.870000  225.640000  227.030000  3.664338e+07
# max    514.790000  515.140000  500.330000  506.090000  1.119850e+08

# %%
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
f, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
f['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
f= f.drop('volume',axis=1)
f.plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.grid()
plt.show()

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ti = TechIndicators(key='YOUR_API_KEY', output_format='pandas')
f, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
f.plot()
plt.title('BBbands indicator for  MSFT stock (60 min)')
plt.show()

# %%
sp = SectorPerformances(key='YOUR_API_KEY', output_format='pandas')
f, meta_data = sp.get_sector()
f['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
f, meta_data = ts.get_intraday(symbol='MSFT',interval='60min', outputsize='full')
f['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (60 min)')
plt.show()
